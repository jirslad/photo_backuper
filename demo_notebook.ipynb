# %%
# clone repo and install photo_backuper package
# !git clone https://github.com/jirslad/photo_backuper.git
# %cd photo_backuper
# %pip install -e photo_backuper
# Out:
# Cloning into 'photo_backuper'...
# remote: Enumerating objects: 190, done.
# remote: Counting objects: 100% (190/190), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 190 (delta 51), reused 182 (delta 43), pack-reused 0
# Receiving objects: 100% (190/190), 99.35 KiB | 1.50 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# /content/photo_backuper
# Obtaining file:///content/photo_backuper/photo_backuper
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: send2trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from photo-backuper==0.1) (1.8.2)
# Installing collected packages: photo-backuper
#   Running setup.py develop for photo-backuper
# Successfully installed photo-backuper-0.1

# %%
# run demo
# !python main.py --demo --mode new_folders --utility_root data/IMAGES/source --source_folder data/IMAGES/source --target_folder data/IMAGES/target
# Out:
# INFO:root:Utility folder from data/IMAGES/source backed up.
# INFO:root:Backing up new folder   1/2: Alpy/2023.9.9 Hochschwab
# INFO:root:Backing up new folder   2/2: Bílé Karpaty/2022.12.11 Lesná, Porážky
# INFO:root:Autogenerating lists of project folders with raw files...
# INFO:root:Backing up finished successfully.
